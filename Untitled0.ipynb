# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
cd '/gdrive/MyDrive/GitConnected/DailyCommit/'

# %%
# !echo "DailyCommit" >> README.md
# !git init
# !git config --global user.email "rlgus33112365@gmail.com"
# !git config --global user.name "greenerous"
# !git add README.md
# !git commit -m "gDrive commit"
# !git branch -M main
# !git remote add origin https://github.com/greenerous/DailyCommit.git

# %%
# !git branch -M main
# !git add .
# !git commit -m "gDrive commit"
# !git push
